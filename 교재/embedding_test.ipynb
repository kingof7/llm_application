# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
upstage_api_key = 'up_FeRaFreJQmiZyVXY5cNGqUwWisws2'

# %%
# pip install openai

from openai import OpenAI # openai==1.52.2

client = OpenAI(
    api_key=upstage_api_key,
    base_url="https://api.upstage.ai/v1"
)

response = client.embeddings.create(
    input="Solar embeddings are awesome",
    model="embedding-query"
)

print(response.data[0].embedding)
# Out:
# [-0.0115509033203125, -0.02691650390625, -0.00852203369140625, 0.006683349609375, -0.0033321380615234375, -0.0027141571044921875, 0.02386474609375, 0.01018524169921875, 0.00502777099609375, 0.00861358642578125, 0.0265655517578125, 0.01654052734375, 0.00595855712890625, -0.012847900390625, 0.0231170654296875, -0.0180511474609375, 0.00951385498046875, 0.0149383544921875, -0.0251922607421875, -0.00765228271484375, 0.0139617919921875, -0.0225982666015625, 0.002658843994140625, -0.01336669921875, 0.0103302001953125, -0.006946563720703125, -0.00884246826171875, -0.004364013671875, 0.017486572265625, 0.01220703125, 0.0195770263671875, 0.01189422607421875, 0.00594329833984375, -0.006961822509765625, 0.0165557861328125, 0.0190887451171875, 0.00970458984375, 0.005916595458984375, -0.0140838623046875, 0.011138916015625, -0.00991058349609375, 0.0008153915405273438, -0.0164794921875, -0.002170562744140625, 0.00371551513671875, 0.00586700439453125, 0.004596710205078125, -0.0220184326171875, 0.0222
# ...

# %%
from openai import OpenAI
import numpy as np

upstage_api_key = "up_FeRaFreJQmiZyVXY5cNGqUwWisws2"

upstage_client = OpenAI(
    api_key=upstage_api_key,
    base_url="https://api.upstage.ai/v1/solar"
)

upstage_king_response = upstage_client.embeddings.create(
    input="king",
    model="solar-embedding-1-large-query"  # Use the correct model name
)

upstage_king_vector = np.array(upstage_king_response)

# %%
upstage_king_similarity = consine_similarity(upstage_king_vector, )
